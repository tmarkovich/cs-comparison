# %% [markdown]
# # Signal Generation

# %% [markdown]
# This simply generates the signal couplet that Vlad wanted to generate in the paper. Note, I've taken on the real part (this shouldn't be an issue) and fixed a sign error that he had.

# %%
import numpy as np
import imp

asdf = np.loadtxt('signal.csv', delimiter=",")

time = asdf[0,:]
signal = asdf[1,:]
del asdf

figure(figsize=(14,10))
plot(time, signal, linewidth=5)

# %% [markdown]
# # Super Resolution

# %%
units = imp.load_source('units',"/Users/tmarkovich/Dropbox/Projects/csfree/units.py")
sr = imp.load_source('sr',"/Users/tmarkovich/Dropbox/Projects/cslibrary/cs.py")

def matrixGeneration(time):
    sr.numOmega = 2500
    sr.numGamma = 50
    sr.gammaMin = 1.5*units.eVtocmm1*units.hbar
    sr.gammaMax = 5*units.eVtocmm1*units.hbar
    
    sr.omegaMin = 0.01*units.eVtocmm1*units.hbar
    sr.omegaMax = 300*units.eVtocmm1*units.hbar
    
    sr.allocateFreqs()
    sr.matrixBuilderDL(time)

sr.method = 'DL'
sr.maxiterm = 4000
dt = np.diff(time)[0]
sr.Verbosity = False

j = 0
tIncluded = 64
reproducedSR = np.zeros((len(time), 4096/64))
errorsSR = np.zeros((3,4096/64))

while tIncluded <= 4096:
    print "j =", j, " and tIncluded =", tIncluded
    timeSlice = time[0:tIncluded]
    matrixGeneration(timeSlice)
    lambdas = sr.l1min(signal[0:tIncluded])
    DOS, reproducedSR[:,j] = sr.constructSeriesDL(time, sr.freq, lambdas)
    
    errorsSR[0,j] = np.linalg.norm(reproducedSR[:,j]-signal , ord=1)/np.linalg.norm(signal, ord=1) 
    errorsSR[1,j] = np.linalg.norm(reproducedSR[:,j]-signal , ord=2)/np.linalg.norm(signal, ord=2) 
    errorsSR[2,j] = np.linalg.norm(reproducedSR[:,j]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)
    
    tIncluded += 64
    j = j + 1
    
np.save('reproduced_SR.npy', reproducedSR)
np.save('errors_SR.npy', errorsSR)
# Out:
# j = 0  and tIncluded = 64
# Using the Drude-Lorentz lineshape
# (50,)
# (64, 125000)
# j =
#  1  and tIncluded = 128
# Using the Drude-Lorentz lineshape
# (50,)
# (128, 125000)
# j =
#  2  and tIncluded = 192
# Using the Drude-Lorentz lineshape
# (50,)
# (192, 125000)
# j =
#  3  and tIncluded = 256
# Using the Drude-Lorentz lineshape
# (50,)
# (256, 125000)
# j =
#  4  and tIncluded = 320
# Using the Drude-Lorentz lineshape
# (50,)
# (320, 125000)
# j =
#  5  and tIncluded = 384
# Using the Drude-Lorentz lineshape
# (50,)
# (384, 125000)
# j =
#  6  and tIncluded = 448
# Using the Drude-Lorentz lineshape
# (50,)
# (448, 125000)
# j =
#  7  and tIncluded = 512
# Using the Drude-Lorentz lineshape
# (50,)
# (512, 125000)
# j =
#  8  and tIncluded = 576
# Using the Drude-Lorentz lineshape
# (50,)
# (576, 125000)
# j =
#  9  and tIncluded = 640
# Using the Drude-Lorentz lineshape
# (50,)
# (640, 125000)
# j =
#  10  and tIncluded = 704
# Using the Drude-Lorentz lineshape
# (50,)
# (704, 125000)
# j =
#  11  and tIncluded = 768
# Using the Drude-Lorentz lineshape
# (50,)
# (768, 125000)
# j =
#  12  and tIncluded = 832
# Using the Drude-Lorentz lineshape
# (50,)
# (832, 125000)
# j =
#  13  and tIncluded = 896
# Using the Drude-Lorentz lineshape
# (50,)
# (896, 125000)
# j =
#  14  and tIncluded = 960
# Using the Drude-Lorentz lineshape
# (50,)
# (960, 125000)
# j =
#  15  and tIncluded = 1024
# Using the Drude-Lorentz lineshape
# (50,)
# (1024, 125000)
# j =
#  16  and tIncluded = 1088
# Using the Drude-Lorentz lineshape
# (50,)
# (1088, 125000)
# j =
#  17  and tIncluded = 1152
# Using the Drude-Lorentz lineshape
# (50,)
# (1152, 125000)
# j =
#  18  and tIncluded = 1216
# Using the Drude-Lorentz lineshape
# (50,)
# (1216, 125000)
# j =
#  19  and tIncluded = 1280
# Using the Drude-Lorentz lineshape
# (50,)
# (1280, 125000)
# j =
#  20  and tIncluded = 1344
# Using the Drude-Lorentz lineshape
# (50,)
# (1344, 125000)
# j =
#  21  and tIncluded = 1408
# Using the Drude-Lorentz lineshape
# (50,)
# (1408, 125000)
# j =
#  22  and tIncluded = 1472
# Using the Drude-Lorentz lineshape
# (50,)
# (1472, 125000)
# j =
#  23  and tIncluded = 1536
# Using the Drude-Lorentz lineshape
# (50,)
# (1536, 125000)
# j =
#  24  and tIncluded = 1600
# Using the Drude-Lorentz lineshape
# (50,)
# (1600, 125000)
# j =
#  25  and tIncluded = 1664
# Using the Drude-Lorentz lineshape
# (50,)
# (1664, 125000)
# j =
#  26  and tIncluded = 1728
# Using the Drude-Lorentz lineshape
# (50,)
# (1728, 125000)
# j =
#  27  and tIncluded = 1792
# Using the Drude-Lorentz lineshape
# (50,)
# (1792, 125000)
# j =
#  28  and tIncluded = 1856
# Using the Drude-Lorentz lineshape
# (50,)
# (1856, 125000)
# j =
#  29  and tIncluded = 1920
# Using the Drude-Lorentz lineshape
# (50,)
# (1920, 125000)
# j =
#  30  and tIncluded = 1984
# Using the Drude-Lorentz lineshape
# (50,)
# (1984, 125000)
# j =
#  31  and tIncluded = 2048
# Using the Drude-Lorentz lineshape
# (50,)
# (2048, 125000)
# j =
#  32  and tIncluded = 2112
# Using the Drude-Lorentz lineshape
# (50,)
# (2112, 125000)
# j =
#  33  and tIncluded = 2176
# Using the Drude-Lorentz lineshape
# (50,)
# (2176, 125000)
# j =
#  34  and tIncluded = 2240
# Using the Drude-Lorentz lineshape
# (50,)
# (2240, 125000)
# j =
#  35  and tIncluded = 2304
# Using the Drude-Lorentz lineshape
# (50,)
# (2304, 125000)
# j =
#  36  and tIncluded = 2368
# Using the Drude-Lorentz lineshape
# (50,)
# (2368, 125000)
# j =
#  37  and tIncluded = 2432
# Using the Drude-Lorentz lineshape
# (50,)
# (2432, 125000)
# j =
#  38  and tIncluded = 2496
# Using the Drude-Lorentz lineshape
# (50,)
# (2496, 125000)
# j =
#  39  and tIncluded = 2560
# Using the Drude-Lorentz lineshape
# (50,)
# (2560, 125000)
# j =
#  40  and tIncluded = 2624
# Using the Drude-Lorentz lineshape
# (50,)
# (2624, 125000)
# j =
#  41  and tIncluded = 2688
# Using the Drude-Lorentz lineshape
# (50,)
# (2688, 125000)
# j =
#  42  and tIncluded = 2752
# Using the Drude-Lorentz lineshape
# (50,)
# (2752, 125000)
# j =
#  43  and tIncluded = 2816
# Using the Drude-Lorentz lineshape
# (50,)
# (2816, 125000)
# j =
#  44  and tIncluded = 2880
# Using the Drude-Lorentz lineshape
# (50,)
# (2880, 125000)
# j =
#  45  and tIncluded = 2944
# Using the Drude-Lorentz lineshape
# (50,)
# (2944, 125000)
# j =
#  46  and tIncluded = 3008
# Using the Drude-Lorentz lineshape
# (50,)
# (3008, 125000)
# j =
#  47  and tIncluded = 3072
# Using the Drude-Lorentz lineshape
# (50,)
# (3072, 125000)
# j =
#  48  and tIncluded = 3136
# Using the Drude-Lorentz lineshape
# (50,)
# (3136, 125000)
# j =
#  49  and tIncluded = 3200
# Using the Drude-Lorentz lineshape
# (50,)
# (3200, 125000)
# j =
#  50  and tIncluded = 3264
# Using the Drude-Lorentz lineshape
# (50,)
# (3264, 125000)
# j =
#  51  and tIncluded = 3328
# Using the Drude-Lorentz lineshape
# (50,)
# (3328, 125000)
# j =
#  52  and tIncluded = 3392
# Using the Drude-Lorentz lineshape
# (50,)
# (3392, 125000)
# j =
#  53  and tIncluded = 3456
# Using the Drude-Lorentz lineshape
# (50,)
# (3456, 125000)
# j =
#  54  and tIncluded = 3520
# Using the Drude-Lorentz lineshape
# (50,)
# (3520, 125000)
# j =
#  55  and tIncluded = 3584
# Using the Drude-Lorentz lineshape
# (50,)
# (3584, 125000)
# j =
#  56  and tIncluded = 3648
# Using the Drude-Lorentz lineshape
# (50,)
# (3648, 125000)
# j =
#  57  and tIncluded = 3712
# Using the Drude-Lorentz lineshape
# (50,)
# (3712, 125000)
# j =
#  58  and tIncluded = 3776
# Using the Drude-Lorentz lineshape
# (50,)
# (3776, 125000)
# j =
#  59  and tIncluded = 3840
# Using the Drude-Lorentz lineshape
# (50,)
# (3840, 125000)
# j =
#  60  and tIncluded = 3904
# Using the Drude-Lorentz lineshape
# (50,)
# (3904, 125000)
# j =
#  61  and tIncluded = 3968
# Using the Drude-Lorentz lineshape
# (50,)
# (3968, 125000)
# j =
#  62  and tIncluded = 4032
# Using the Drude-Lorentz lineshape
# (50,)
# (4032, 125000)
# j =
#  63  and tIncluded = 4096
# Using the Drude-Lorentz lineshape
# (50,)
# (4096, 125000)

# %% [markdown]
# # Compressed Sensing

# %%
units = imp.load_source('units',"/Users/tmarkovich/Dropbox/Projects/csfree/units.py")
sr = imp.load_source('sr',"/Users/tmarkovich/Dropbox/Projects/cslibrary/cs.py")

def matrixGeneration(time):
    sr.numOmega = 2500
    sr.numGamma = 50
    sr.gammaMin = 1.5*units.eVtocmm1*units.hbar
    sr.gammaMax = 5*units.eVtocmm1*units.hbar
    
    sr.omegaMin = 0.01*units.eVtocmm1*units.hbar
    sr.omegaMax = 300*units.eVtocmm1*units.hbar
    
    sr.allocateFreqs()
    sr.matrixBuilderDL(time)

sr.method = 'DL'
sr.maxiterm = 4000
dt = np.diff(time)[0]
sr.Verbosity = False

j = 0
tIncluded = 64
reproducedCS = np.zeros((len(time), 4096/64))
errorsCS = np.zeros((3,4096/64))

indices = np.arange(time.size)
np.random.shuffle(indices)

while tIncluded <= 4096:
    print "j =", j, " and tIncluded =", tIncluded

    idx = np.sort(indices[0:tIncluded])
    timeSlice = np.sort(time[idx])
    matrixGeneration(timeSlice)
    lambdas = sr.l1min(signal[idx])
    DOS, reproducedCS[:,j] = sr.constructSeriesDL(time, sr.freq, lambdas)
    
    errorsCS[0,j] = np.linalg.norm(reproducedCS[:,j]-signal , ord=1)/np.linalg.norm(signal, ord=1) 
    errorsCS[1,j] = np.linalg.norm(reproducedCS[:,j]-signal , ord=2)/np.linalg.norm(signal, ord=2) 
    errorsCS[2,j] = np.linalg.norm(reproducedCS[:,j]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)
    
    tIncluded += 64
    j = j + 1
    
np.save('reproduced_CS.npy', reproducedCS)
np.save('errors_CS.npy', errorsCS)
# Out:
# j = 0  and tIncluded = 64
# Using the Drude-Lorentz lineshape
# (50,)
# (64, 125000)
# j =
#  1  and tIncluded = 128
# Using the Drude-Lorentz lineshape
# (50,)
# (128, 125000)
# j =
#  2  and tIncluded = 192
# Using the Drude-Lorentz lineshape
# (50,)
# (192, 125000)
# j =
#  3  and tIncluded = 256
# Using the Drude-Lorentz lineshape
# (50,)
# (256, 125000)
# j =
#  4  and tIncluded = 320
# Using the Drude-Lorentz lineshape
# (50,)
# (320, 125000)
# j =
#  5  and tIncluded = 384
# Using the Drude-Lorentz lineshape
# (50,)
# (384, 125000)
# j =
#  6  and tIncluded = 448
# Using the Drude-Lorentz lineshape
# (50,)
# (448, 125000)
# j =
#  7  and tIncluded = 512
# Using the Drude-Lorentz lineshape
# (50,)
# (512, 125000)
# j =
#  8  and tIncluded = 576
# Using the Drude-Lorentz lineshape
# (50,)
# (576, 125000)
# j =
#  9  and tIncluded = 640
# Using the Drude-Lorentz lineshape
# (50,)
# (640, 125000)
# j =
#  10  and tIncluded = 704
# Using the Drude-Lorentz lineshape
# (50,)
# (704, 125000)
# j =
#  11  and tIncluded = 768
# Using the Drude-Lorentz lineshape
# (50,)
# (768, 125000)
# j =
#  12  and tIncluded = 832
# Using the Drude-Lorentz lineshape
# (50,)
# (832, 125000)
# j =
#  13  and tIncluded = 896
# Using the Drude-Lorentz lineshape
# (50,)
# (896, 125000)
# j =
#  14  and tIncluded = 960
# Using the Drude-Lorentz lineshape
# (50,)
# (960, 125000)
# j =
#  15  and tIncluded = 1024
# Using the Drude-Lorentz lineshape
# (50,)
# (1024, 125000)
# j =
#  16  and tIncluded = 1088
# Using the Drude-Lorentz lineshape
# (50,)
# (1088, 125000)
# j =
#  17  and tIncluded = 1152
# Using the Drude-Lorentz lineshape
# (50,)
# (1152, 125000)
# j =
#  18  and tIncluded = 1216
# Using the Drude-Lorentz lineshape
# (50,)
# (1216, 125000)
# j =
#  19  and tIncluded = 1280
# Using the Drude-Lorentz lineshape
# (50,)
# (1280, 125000)
# j =
#  20  and tIncluded = 1344
# Using the Drude-Lorentz lineshape
# (50,)
# (1344, 125000)
# j =
#  21  and tIncluded = 1408
# Using the Drude-Lorentz lineshape
# (50,)
# (1408, 125000)
# j =
#  22  and tIncluded = 1472
# Using the Drude-Lorentz lineshape
# (50,)
# (1472, 125000)
# j =
#  23  and tIncluded = 1536
# Using the Drude-Lorentz lineshape
# (50,)
# (1536, 125000)
# j =
#  24  and tIncluded = 1600
# Using the Drude-Lorentz lineshape
# (50,)
# (1600, 125000)
# j =
#  25  and tIncluded = 1664
# Using the Drude-Lorentz lineshape
# (50,)
# (1664, 125000)
# j =
#  26  and tIncluded = 1728
# Using the Drude-Lorentz lineshape
# (50,)
# (1728, 125000)
# j =
#  27  and tIncluded = 1792
# Using the Drude-Lorentz lineshape
# (50,)
# (1792, 125000)
# j =
#  28  and tIncluded = 1856
# Using the Drude-Lorentz lineshape
# (50,)
# (1856, 125000)
# j =
#  29  and tIncluded = 1920
# Using the Drude-Lorentz lineshape
# (50,)
# (1920, 125000)
# j =
#  30  and tIncluded = 1984
# Using the Drude-Lorentz lineshape
# (50,)
# (1984, 125000)
# j =
#  31  and tIncluded = 2048
# Using the Drude-Lorentz lineshape
# (50,)
# (2048, 125000)
# j =
#  32  and tIncluded = 2112
# Using the Drude-Lorentz lineshape
# (50,)
# (2112, 125000)
# j =
#  33  and tIncluded = 2176
# Using the Drude-Lorentz lineshape
# (50,)
# (2176, 125000)
# j =
#  34  and tIncluded = 2240
# Using the Drude-Lorentz lineshape
# (50,)
# (2240, 125000)
# j =
#  35  and tIncluded = 2304
# Using the Drude-Lorentz lineshape
# (50,)
# (2304, 125000)
# j =
#  36  and tIncluded = 2368
# Using the Drude-Lorentz lineshape
# (50,)
# (2368, 125000)
# j =
#  37  and tIncluded = 2432
# Using the Drude-Lorentz lineshape
# (50,)
# (2432, 125000)
# j =
#  38  and tIncluded = 2496
# Using the Drude-Lorentz lineshape
# (50,)
# (2496, 125000)
# j =
#  39  and tIncluded = 2560
# Using the Drude-Lorentz lineshape
# (50,)
# (2560, 125000)
# j =
#  40  and tIncluded = 2624
# Using the Drude-Lorentz lineshape
# (50,)
# (2624, 125000)
# j =
#  41  and tIncluded = 2688
# Using the Drude-Lorentz lineshape
# (50,)
# (2688, 125000)
# j =
#  42  and tIncluded = 2752
# Using the Drude-Lorentz lineshape
# (50,)
# (2752, 125000)
# j =
#  43  and tIncluded = 2816
# Using the Drude-Lorentz lineshape
# (50,)
# (2816, 125000)
# j =
#  44  and tIncluded = 2880
# Using the Drude-Lorentz lineshape
# (50,)
# (2880, 125000)
# j =
#  45  and tIncluded = 2944
# Using the Drude-Lorentz lineshape
# (50,)
# (2944, 125000)
# j =
#  46  and tIncluded = 3008
# Using the Drude-Lorentz lineshape
# (50,)
# (3008, 125000)
# j =
#  47  and tIncluded = 3072
# Using the Drude-Lorentz lineshape
# (50,)
# (3072, 125000)
# j =
#  48  and tIncluded = 3136
# Using the Drude-Lorentz lineshape
# (50,)
# (3136, 125000)
# j =
#  49  and tIncluded = 3200
# Using the Drude-Lorentz lineshape
# (50,)
# (3200, 125000)
# j =
#  50  and tIncluded = 3264
# Using the Drude-Lorentz lineshape
# (50,)
# (3264, 125000)
# j =
#  51  and tIncluded = 3328
# Using the Drude-Lorentz lineshape
# (50,)
# (3328, 125000)
# j =
#  52  and tIncluded = 3392
# Using the Drude-Lorentz lineshape
# (50,)
# (3392, 125000)
# j =
#  53  and tIncluded = 3456
# Using the Drude-Lorentz lineshape
# (50,)
# (3456, 125000)
# j =
#  54  and tIncluded = 3520
# Using the Drude-Lorentz lineshape
# (50,)
# (3520, 125000)
# j =
#  55  and tIncluded = 3584
# Using the Drude-Lorentz lineshape
# (50,)
# (3584, 125000)
# j =
#  56  and tIncluded = 3648
# Using the Drude-Lorentz lineshape
# (50,)
# (3648, 125000)
# j =
#  57  and tIncluded = 3712
# Using the Drude-Lorentz lineshape
# (50,)
# (3712, 125000)
# j =
#  58  and tIncluded = 3776
# Using the Drude-Lorentz lineshape
# (50,)
# (3776, 125000)
# j =
#  59  and tIncluded = 3840
# Using the Drude-Lorentz lineshape
# (50,)
# (3840, 125000)
# j =
#  60  and tIncluded = 3904
# Using the Drude-Lorentz lineshape
# (50,)
# (3904, 125000)
# j =
#  61  and tIncluded = 3968
# Using the Drude-Lorentz lineshape
# (50,)
# (3968, 125000)
# j =
#  62  and tIncluded = 4032
# Using the Drude-Lorentz lineshape
# (50,)
# (4032, 125000)
# j =
#  63  and tIncluded = 4096
# Using the Drude-Lorentz lineshape
# (50,)
# (4096, 125000)

# %% [markdown]
# # Filter Diagonalization

# %%
harminv = imp.load_source('harminv',"/Users/tmarkovich/Dropbox/Projects/cslibrary/harminv.py")

NF_MAX = 1400
NF_MIN = 2200
harminv.NF_MAX = NF_MAX
harminv.NF_MIN = NF_MIN
dt = 1.0
n = 1.0
dens = 1.0
harminv.dens = dens
fmin = -1.0
fmax = 1.0
nf = (fmax - fmin)*dt*n*dens

DEBUG = True

if nf > NF_MAX:
    nf = NF_MAX
elif nf < NF_MIN:
    nf = NF_MIN
else:
    nf = nf
n = len(signal)


reproducedHI = np.zeros((len(time), 4096/64), dtype=np.complex128)
errorsHI = np.zeros((3,4096/64))
j = 0
tIncluded = 64

while tIncluded <= 4096:
    print "j =", j, " and tIncluded =", tIncluded
    n = len(signal[0:tIncluded])
    
    harminv.dataCreate(n, signal, fmin*dt, fmax*dt, nf)
    harminv.solve_once()
    harminv.compute_amps()
    
    reproducedHI[:,j] = harminv.reproduce(time)
    errorsHI[0, j] = np.linalg.norm(reproducedHI[:,j]-signal , ord=1)/np.linalg.norm(signal, ord=1) 
    errorsHI[1, j] = np.linalg.norm(reproducedHI[:,j]-signal , ord=2)/np.linalg.norm(signal, ord=2) 
    errorsHI[2, j] = np.linalg.norm(reproducedHI[:,j]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)
    filename = 'parameters'+str(j)+'.txt'
    np.save(filename, harminv.data.u)
    tIncluded += 64
    j += 1

np.save('reproduced_HI.npy', reproducedHI)
np.save('errors_HI.npy', errorsHI)
# Out:
# start
# j = 0  and tIncluded = 64
# j =
#  1  and tIncluded = 128
# j =
#  2  and tIncluded = 192
# j =
#  3  and tIncluded = 256
# j =
#  4  and tIncluded = 320
# j =
#  5  and tIncluded = 384
# j =
#  6  and tIncluded = 448
# j =
#  7  and tIncluded = 512
# j =
#  8  and tIncluded = 576
# j =
#  9  and tIncluded = 640
# j =
#  10  and tIncluded = 704
# j =
#  11  and tIncluded = 768
# j =
#  12  and tIncluded = 832
# j =
#  13  and tIncluded = 896
# j =
#  14  and tIncluded = 960
# j =
#  15  and tIncluded = 1024
# j =
#  16  and tIncluded = 1088
# j =
#  17  and tIncluded = 1152
# j =
#  18  and tIncluded = 1216
# j =
#  19  and tIncluded = 1280
# j =
#  20  and tIncluded = 1344
# j =
#  21  and tIncluded = 1408
# j =
#  22  and tIncluded = 1472
# j =
#  23  and tIncluded = 1536
# j =
#  24  and tIncluded = 1600
# j =
#  25  and tIncluded = 1664
# j =
#  26  and tIncluded = 1728
# j =
#  27  and tIncluded = 1792
# j =
#  28  and tIncluded = 1856
# j =
#  29  and tIncluded = 1920
# j =
#  30  and tIncluded = 1984
# j =
#  31  and tIncluded = 2048
# j =
#  32  and tIncluded = 2112
# j =
#  33  and tIncluded = 2176
# j =
#  34  and tIncluded = 2240
# j =
#  35  and tIncluded = 2304
# j =
#  36  and tIncluded = 2368
# j =
#  37  and tIncluded = 2432
# j =
#  38  and tIncluded = 2496
# j =
#  39  and tIncluded = 2560
# j =
#  40  and tIncluded = 2624
# j =
#  41  and tIncluded = 2688
# j =
#  42  and tIncluded = 2752
# j =
#  43  and tIncluded = 2816
# j =
#  44  and tIncluded = 2880
# j =
#  45  and tIncluded = 2944
# j =
#  46  and tIncluded = 3008
# j =
#  47  and tIncluded = 3072
# j =
#  48  and tIncluded = 3136
# j =
#  49  and tIncluded = 3200
# j =
#  50  and tIncluded = 3264
# j =
#  51  and tIncluded = 3328
# j =
#  52  and tIncluded = 3392
# j =
#  53  and tIncluded = 3456
# j =
#  54  and tIncluded = 3520
# j =
#  55  and tIncluded = 3584
# j =
#  56  and tIncluded = 3648
# j =
#  57  and tIncluded = 3712
# j =
#  58  and tIncluded = 3776
# j =
#  59  and tIncluded = 3840
# j =
#  60  and tIncluded = 3904
# j =
#  61  and tIncluded = 3968
# j =
#  62  and tIncluded = 4032
# j =
#  63  and tIncluded = 4096

# %% [markdown]
# # Error Plotting

# %%
figure(figsize=(14, 10))
plot(np.log(errorsCS[1,:]), linewidth='5')
plot(np.log(errorsSR[1,:]), linewidth='5')
plot(np.log(errorsHI[1,:]), linewidth='5')
legend(('CS','SR','FDM'))

# %% [markdown]
# # Error Plotting

# %%
errors_CS = np.load('errors_CS.npy')
errors_SR = np.load('errors_SR.npy')
errors_HI = np.load('errors_HI.npy')

print errors_CS

figure(figsize=(14, 10))
plot(np.log10(errors_CS[1,:]), linewidth='5')
plot(np.log10(errors_SR[1,:]), linewidth='5')
plot(np.log10(errors_HI[1,:]), linewidth='5')
# Out:
# [[ 0.68165223  0.46482601  0.36500498  0.299331    0.29424844  0.28405235
#    0.27730727  0.28304769  0.25991703  0.23674787  0.27398704  0.27807435
#    0.26775488  0.26214058  0.26545268  0.26349048  0.25673773  0.26256718
#    0.25854454  0.2156303   0.22136741  0.230108    0.21408031  0.21498508
#    0.21270191  0.26259007  0.26301403  0.26294441  0.26085733  0.21821311
#    0.25252217  0.25280406  0.25161372  0.2505205   0.24951362  0.24479399
#    0.23654799  0.2348124   0.23584458  0.23979264  0.24545858  0.24633205
#    0.244432    0.24951983  0.24799421  0.24817218  0.24861574  0.23631443
#    0.23834232  0.24008565  0.23933144  0.2453372   0.24563376  0.24114511
#    0.24578918  0.24537816  0.24548446  0.24478887  0.24529929  0.2451556
#    0.24555845  0.24557106  0.24495671  0.24493338]
#  [ 0.71429706  0.49465687  0.35531712  0.28787626  0.28595288  0.26683086
#    0.25170288  0.25679706  0.23412798  0.23090949  0.22201831  0.22967372
#    0.2100107   0.20455686  0.21028015  0.21026915  0.20197598  0.20754676
#    0.20606967  0.184535    0.19268075  0.19880286  0.19177752  0.19304367
#    0.19379215  0.20746931  0.20747459  0.2071489   0.20583218  0.18638438
#    0.20205261  0.2015365   0.20129584  0.20093198  0.20001321  0.19478371
#    0.18621045  0.18527954  0.18523506  0.18891734  0.19298425  0.19454977
#    0.19228126  0.19840141  0.19829654  0.19884329  0.19792575  0.18518795
#    0.18691237  0.18726004  0.18732425  0.19211958  0.19242782  0.18817405
#    0.19205947  0.19196542  0.19181503  0.19131233  0.19125398  0.19142408
#    0.19199606  0.19211695  0.19125033  0.19096845]
#  [ 0.33472156  0.30781266  0.30065476  0.23787867  0.26321439  0.14971234
#    0.17539642  0.19370574  0.17761639  0.22625009  0.14195281  0.15790692
#    0.11081197  0.10704466  0.1174127   0.11132956  0.10562357  0.11578589
#    0.11753252  0.13205301  0.1477606   0.15553451  0.1602742   0.16181691
#    0.16798946  0.1263954   0.12885384  0.12594976  0.12616584  0.13788799
#    0.11314775  0.10384335  0.10843387  0.11015525  0.10563195  0.0957248
#    0.08148864  0.07718358  0.07880727  0.0854357   0.09267304  0.09513178
#    0.09499681  0.1060503   0.10863831  0.11099977  0.10703183  0.08035498
#    0.08442454  0.08523864  0.08570295  0.09408394  0.09395742  0.08661072
#    0.0939938   0.09452088  0.09588531  0.09458466  0.09538192  0.09686959
#    0.09878005  0.10096706  0.09909105  0.09965936]]
