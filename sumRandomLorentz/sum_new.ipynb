# %%
import numpy as np
import imp
import csv

cs_utils = imp.load_source('cs_utils',"/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/cs_utils.py")
drude_lorentz = imp.load_source('cs_utils',"/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/drude_lorentz.py")
Astruct = imp.load_source('Astruct', '/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/Astruct.py')
twist = imp.load_source('twist',"/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/TwIST_Solver.py")
time_range = np.array([2**12, 2**11, 2**10, 2**9, 2**8, 2**7, 2**6, 2**5, 2**4, 2**3, 2**2, 2**1, 2**0])

# import pint for some unit special sauce
from pint import UnitRegistry
ureg = UnitRegistry()
ureg.enable_contexts('spectroscopy')
ureg.enable_contexts('boltzmann')
Q_ = ureg.Quantity

print time_range
# Out:
# [4096 2048 1024  512  256  128   64   32   16    8    4    2    1]

# %%
def signal_load():
    asdf = np.loadtxt('signal.csv', delimiter=",")
    time = asdf[0,:]
    signal = asdf[1,:]
    return time*ureg.second, signal

def reproduction(time, signal, lambdas, A, plotting = False):
    reproduced = np.zeros(shape=np.shape(time))
    reproduced += cs_utils.reproduce_series(A, lambdas, time)

    if(plotting):
        cs_utils.thomas_ploting(time, [signal, reproduced], 
                                title='Original Signal vs Reproduction',
                                legend_label=['Original Signal', 'Reproduced'],
                                xlabel='Time [s]',
                                ylabel='Signal [Arb]')
    return reproduced


def matrixGeneration(x, omegaMin = 0.01, omegaMax = 300, numOmega = 250, gammaMin = 1.5, gammaMax = 5, numGamma = 50):
    # Param Array Generation
    gamma_grid = np.linspace(gammaMin, gammaMax, num=numGamma)*ureg.Hz
    omega_grid = np.linspace(omegaMin, omegaMax, num=numOmega)*ureg.Hz
    length = len(gamma_grid)*len(omega_grid)
    gammaList = np.zeros(shape=(length, 1))
    omegaList = np.zeros(shape=(length, 1))

    ind = 0
    for i in xrange(np.shape(gamma_grid)[0]):
        for j in xrange(np.shape(omega_grid)[0]):
            gammaList[ind] = gamma_grid[i].magnitude
            omegaList[ind] = omega_grid[j].magnitude
            ind += 1
    param_array = np.hstack((gammaList, omegaList))*ureg.Hz

    A = Astruct.Astruct(drude_lorentz.time, 
                  x.to('second').magnitude, 
                  param_array.to('Hz').magnitude)
    A.matrix = cs_utils.matrix_maker(A)
    return A

# %%
time, signal = signal_load()

# Main loop that adds successively more time
reproduced = np.zeros((len(time), len(time_range)))
errors = np.zeros(shape=(3, len(time_range)))

for i in range(len(time_range)):
    print "j =", i
    timeSlice = time[::time_range[i]]
    signalSlice = signal[::time_range[i]]

    A = matrixGeneration(timeSlice)
    twist.tolA = 1e-7
    twist.tolD = 1e-9
    twist.verbose = False
    print np.shape(A.matrix)
    print np.shape(signalSlice)
    lambdas, lambdas_debias, objective, times, debias_start, max_svd = twist.solve(signalSlice, A.matrix)
    reproduced[:,i] = reproduction(time.to('second').magnitude, signal, lambdas_debias, A, plotting = False)

    errors[0, i] = np.linalg.norm(reproduced[:,i]-signal , ord=1)/np.linalg.norm(signal, ord=1) 
    errors[1, i] = np.linalg.norm(reproduced[:,i]-signal , ord=2)/np.linalg.norm(signal, ord=2) 
    errors[2, i] = np.linalg.norm(reproduced[:,i]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)

np.save('reproduced_SR.npy', reproduced)
np.save('errors_SR.npy', errors)

errors_SR = errors
reproduced_SR = reproduced

figure(figsize=(14, 10))
plot(signal, linewidth='5')
plot(reproduced_SR[:,8], linewidth='3')

figure(figsize=(14, 10))
plot(np.log10(errors_SR[1,:]), linewidth='5')
# Out:
# j = 0
# (1, 12500)
# (1,)
# j =
#  1
# (2, 12500)
# (2,)
# j =
#  2
# (4, 12500)
# (4,)
# j =
#  3
# (8, 12500)
# (8,)
# j =
#  4
# (16, 12500)
# (16,)
# j =
#  5
# (32, 12500)
# (32,)
# j =
#  6
# (64, 12500)
# (64,)
# j =
#  7
# (128, 12500)
# (128,)
# j =
#  8
# (256, 12500)
# (256,)
# j =
#  9
# (512, 12500)
# (512,)
# j =
#  10
# (1024, 12500)
# (1024,)
# j =
#  11
# (2048, 12500)
# (2048,)
# j =
#  12
# (4096, 12500)
# (4096,)

# %%
time, signal = signal_load()
reproduced = np.zeros((len(time), len(time_range)))
errors = np.zeros(shape=(3, len(time_range)))
indices = np.arange(time.size)
np.random.shuffle(indices)

for i in range(len(time_range)):
    print "j =", i
    idx = np.sort(indices[0:len(time[::time_range[i]])])
    timeSlice = time[idx]
    signalSlice = signal[idx]

    A = matrixGeneration(timeSlice)
    twist.tolA = 1e-7
    twist.tolD = 1e-9
    twist.verbose = False
    lambdas, lambdas_debias, objective, times, debias_start, max_svd = twist.solve(signalSlice, A.matrix)
    reproduced[:,i] = reproduction(time.to('second').magnitude, signal, lambdas_debias, A, plotting = False)

    errors[0, i] = np.linalg.norm(reproduced[:,i]-signal , ord=1)/np.linalg.norm(signal, ord=1)
    errors[1, i] = np.linalg.norm(reproduced[:,i]-signal , ord=2)/np.linalg.norm(signal, ord=2)
    errors[2, i] = np.linalg.norm(reproduced[:,i]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)


np.save('reproduced_CS.npy', reproduced)
np.save('errors_CS.npy', errors)

errors_CS = errors
reproduced_CS = reproduced

figure(figsize=(14, 10))
plot(signal, linewidth='5')
plot(reproduced_CS[:,8], linewidth='3')

figure(figsize=(14, 10))
plot(np.log10(errors_CS[1,:]), linewidth='5')
# Out:
# j = 0
# j =
#  1
# j =
#  2
# j =
#  3
# j =
#  4
# j =
#  5
# j =
#  6
# j =
#  7
# j =
#  8
# j =
#  9
# j =
#  10
# j =
#  11
# j =
#  12
# /Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/TwIST_Solver.py:303: RuntimeWarning: divide by zero encountered in double_scalars
#   alpha_cg = rTr_cg / np.sum(pvec * Apvec)
# /Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/TwIST_Solver.py:305: RuntimeWarning: invalid value encountered in multiply
#   x_debias = x_debias + alpha_cg * pvec
# /Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/TwIST_Solver.py:306: RuntimeWarning: invalid value encountered in multiply
#   resid = resid + alpha_cg * RWpvec
# /Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslib2/TwIST_Solver.py:307: RuntimeWarning: invalid value encountered in multiply
#   rvec = rvec + alpha_cg * Apvec

# %%
time, signal = signal_load()
time = time.to('second').magnitude

# Harmonic Inversion part of the comparison
harminv = imp.load_source('harminv',"/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslibrary/harminv.py")

NF_MAX = 1100
NF_MIN = 2400
harminv.NF_MAX = NF_MAX
harminv.NF_MIN = NF_MIN
dt = 1.0
n = 1.2
dens = 1.0
harminv.dens = dens
fmin = -1.0
fmax = 1.0
nf = (fmax - fmin)*dt*n*dens

DEBUG = True

if nf > NF_MAX:
    nf = NF_MAX
elif nf < NF_MIN:
    nf = NF_MIN
else:
    nf = nf
n = len(signal)

reproduced = np.zeros((len(time), len(time_range)), dtype=np.complex128)
errors = np.zeros(shape=(3, len(time_range)))

for i in range(len(time_range)):
    print "j =", i
    timeSlice = time[::time_range[i]]
    signalSlice = signal[::time_range[i]]

    n = len(signalSlice)
    harminv.dataCreate(n, signal, fmin*dt, fmax*dt, nf)
    harminv.solve_once()
    harminv.compute_amps()
    reproduced[:,i] = harminv.reproduce(time)

    errors[0, i] = np.linalg.norm(reproduced[:, i]-signal , ord=1)/np.linalg.norm(signal, ord=1)
    errors[1, i] = np.linalg.norm(reproduced[:, i]-signal , ord=2)/np.linalg.norm(signal, ord=2)
    errors[2, i] = np.linalg.norm(reproduced[:, i]-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)

    filename = 'parameters'+str(i)+'.txt'
    np.save(filename, harminv.data.u)

np.save('reproduced_HI.npy', reproduced)
np.save('errors_HI.npy', errors)

figure(figsize=(14, 10))
plot(signal, linewidth='5')
plot(reproduced[:,8], linewidth='3')

figure(figsize=(14, 10))
plot(np.log10(errors_HI[1,:]), linewidth='5')
# Out:
# start
# j = 1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-da23f1da2fda> in <module>()
#      37     n = len(signalSlice)
#      38     harminv.dataCreate(n, signal, fmin*dt, fmax*dt, nf)
# ---> 39     harminv.solve_once()
#      40     harminv.compute_amps()
#      41     reproduced[:,i] = harminv.reproduce(time)
#
# /Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslibrary/harminv.pyc in solve_once()
#     318                 v0[j] = v0[i]
#     319                 v0[i] = 0.0
# --> 320             s = 1/cmath.sqrt(v0[i])
#     321             if DEBUG:
#     322                 print "s = ", s, " j =", j
#
# ZeroDivisionError: complex division by zero

# %%
# Out:
# [  0.00000000e+00   2.44200244e-04   4.88400488e-04 ...,   9.99511600e-01
#    9.99755800e-01   1.00000000e+00] second

# %%
errors_CS = np.load('errors_CS.npy')
errors_SR = np.load('errors_SR.npy')
#errors_HI = np.load('errors_HI.npy')

print np.shape(time_range), np.shape(errors_CS[1, :])

figure(figsize=(14, 10))
plot(np.log10(errors_CS[1,:]), linewidth='5')
plot(np.log10(errors_SR[1,:]), linewidth='5')
#plot(np.log10(errors_HI[1,:]), linewidth='5')
legend(['CS','SR','HI'])
# Out:
# (13,) (13,)

# %%
cs_utils.thomas_ploting([x, x, x],
                        [np.log10(errors_CS[1,:]), np.log10(errors_SR[1,:]), np.log10(errors_HI[1,:])],
                        legend_label = ['CS','SR','HI'],
                        title='Log Plot of Reproduction Errors',
                        ylabel='Log Error',
                        xlabel='Number of points included as a power of 2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2d126acf50a7> in <module>()
# ----> 1 cs_utils.thomas_ploting([x, x, x],
#       2                         [np.log10(errors_CS[1,:]), np.log10(errors_SR[1,:])],
#       3                         legend_label = ['CS','SR','HI'],
#       4                         title='Log Plot of Reproduction Errors',
#       5                         ylabel='Log Error',
#
# NameError: name 'x' is not defined

# %%
time, signal = signal_load()
time = time.to('second').magnitude

# Harmonic Inversion part of the comparison
harminv = imp.load_source('harminv',"/Users/tmarkovich/Dropbox (Aspuru-Guzik Lab)/Projects/cslibrary/harminv.py")

NF_MAX = 1800
NF_MIN = 1200
harminv.NF_MAX = NF_MAX
harminv.NF_MIN = NF_MIN
dt = 2.0
n = 1.0
dens = 30.0
harminv.dens = dens
fmin = -100.0
fmax = 100.0
nf = (fmax - fmin)*dt*n*dens

DEBUG = True

if nf > NF_MAX:
    nf = NF_MAX
elif nf < NF_MIN:
    nf = NF_MIN
else:
    nf = nf
n = len(signal)

print "nf = ", nf

harminv.dataCreate(n, signal, fmin*dt, fmax*dt, nf)
harminv.solve_once()
harminv.compute_amps()
reproduced = harminv.reproduce(time)

print "l1 error = ", np.linalg.norm(reproduced-signal , ord=1)/np.linalg.norm(signal, ord=1)
print "l2 error = ", np.linalg.norm(reproduced-signal , ord=2)/np.linalg.norm(signal, ord=2)
print "linf error = ", np.linalg.norm(reproduced-signal , ord=np.inf)/np.linalg.norm(signal, ord=np.inf)

figure(figsize=(14, 10))
plot(signal, linewidth='5')
plot(reproduced, linewidth='3')
# Out:
# start
# nf =
#  1800
# l1 error =
#  0.156238883415
# l2 error =  0.268144621518
# linf error =  0.330032661
